# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\vqa78999\\OneDrive - Science and Technology Facilities Council\\Documents\\Training\\Archer Python Course\\portal-teachingdb-master'

# %%
import pandas as pd

# %%
surveys_df = pd.read_csv('surveys.csv')

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
#group data by plot_id and by sex
by_site_sex = surveys_df.groupby(['plot_id', 'sex'])

# %%
#show what this looks like, but ensure showing numeric only 
by_site_sex.mean(numeric_only=True)
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# plot_id sex
# 1       F    18390.384434  6.597877  15.338443  1990.933962        31.733911
#         M    17197.740639  6.121461  15.905936  1990.091324        34.302770
# 2       F    17714.753608  6.426804  16.288660  1990.449485        30.161220
#         M    18085.458042  6.340035  15.440559  1990.756119        30.353760
# 3       F    19888.783875  6.610302  15.993281  1992.013438        23.774044
#         M    20226.767857  6.277381  16.271429  1992.275000        23.833744
# 4       F    17489.205275  6.447248  15.608945  1990.235092        33.249102
#         M    18493.841748  6.436893  16.303883  1991.000971        34.097959
# 5       F    12280.793169  6.142315  15.722960  1986.485769        28.921844
#         M    12798.426621  6.194539  15.703072  1986.817406        29.694794
# 6       F    19406.503392  6.640434  15.947083  1991.579376        26.981322
# ...

# %%
#now we just want the weight column and we want to show the total weight for each sex in each site
#give the object a name,call the previous object, limit this to the relevant column, define how this column will be aggregated

site_sex_count = by_site_sex['weight'].sum()
site_sex_count
# Out:
# plot_id  sex
# 1        F      38253.0
#          M      59979.0
# 2        F      50144.0
#          M      57250.0
# 3        F      27251.0
#          M      28253.0
# 4        F      39796.0
#          M      49377.0
# 5        F      21143.0
#          M      23326.0
# 6        F      26210.0
#          M      27245.0
# 7        F       6522.0
#          M       6422.0
# 8        F      37274.0
#          M      47755.0
# 9        F      44128.0
#          M      48727.0
# 10       F       2359.0
#          M       2776.0
# 11       F      34638.0
#          M      43106.0
# 12       F      51825.0
#          M      57420.0
# 13       F      24720.0
#          M      30354.0
# 14       F      32770.0
#          M      46469.0
# 15       F      12455.0
#          M      11037.0
# 16       F       5446.0
#          M       6310.0
# 17       F      42106.0
#          M      48082.0
# 18       F      27353.0
#          M      26433.0
# 19       F      11297.0
# ...

# %%
spc = site_sex_count.unstack()
spc
# Out:
# sex            F        M
# plot_id
# 1        38253.0  59979.0
# 2        50144.0  57250.0
# 3        27251.0  28253.0
# 4        39796.0  49377.0
# 5        21143.0  23326.0
# 6        26210.0  27245.0
# 7         6522.0   6422.0
# 8        37274.0  47755.0
# 9        44128.0  48727.0
# 10        2359.0   2776.0
# 11       34638.0  43106.0
# 12       51825.0  57420.0
# 13       24720.0  30354.0
# 14       32770.0  46469.0
# 15       12455.0  11037.0
# 16        5446.0   6310.0
# 17       42106.0  48082.0
# 18       27353.0  26433.0
# 19       11297.0  11514.0
# 20       33206.0  25988.0
# 21       15481.0   9815.0
# 22       34656.0  35363.0
# 23        3352.0   3883.0
# 24       22951.0  18835.0

# %%
#draw a bar chart which is stacked
#add axes labels and a title

s_plot = spc.plot(kind='bar', stacked=True)
s_plot.set_ylabel("Weight")
s_plot.set_xlabel("Plot")
s_plot.set_title("Total weight by plot and sex")
# Out:
# Text(0.5, 1.0, 'Total weight by plot and sex')
