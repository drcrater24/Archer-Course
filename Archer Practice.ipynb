# %%
# This is where we'll run the code we're practicing
#

# %%
numbers = [1,2,3]
for num in numbers:
    print(num)
# Out:
# 1
# 2
# 3

# %%
numbers.append(4)
for num in numbers:
    print(num)
# Out:
# 1
# 2
# 3
# 4

# %%
a_tuple = (1,2,3)
a_list = [1,2,3]
another_tuple = ('blue', 'green', 'red')

# %%
a_list[1] = 5
for num in a_list:
    print(num)
# Out:
# 1
# 5
# 3

# %%
a_tuple[2] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a_tuple[2] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
type(a_tuple)
# Out:
# tuple

# %%
len(a_tuple)
# Out:
# 3

# %%
len(a_list)
# Out:
# 3

# %%
rev = {'first': 'one', 'second' : 'two', 'third': 'three'}

# %%
for key in rev.keys():
    print(key,': ',rev[key])
# Out:
# first :  one
# second :  two
# third :  three

# %%
rev['second'] = 2

# %%
for key in rev.keys():
    print(key,': ',rev[key])
# Out:
# first :  one
# second :  2
# third :  three

# %%
import os

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/os.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\vqa78999'

# %%
os.listdir()
# Out:
# ['.conda',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'Archer Practice.ipynb',
#  'Archer Session 2.ipynb',
#  'Archer Session 3.ipynb',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{b2267007-481b-11ee-8fee-0c3796a9b1f2}.TM.blf',
#  'NTUSER.DAT{b2267007-481b-11ee-8fee-0c3796a9b1f2}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{b2267007-481b-11ee-8fee-0c3796a9b1f2}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'OneDrive - Science and Technology Facilities Council',
#  'PrintHood',
#  'PSAppDeployToolkit',
#  'Recent',
#  'Saved Games',
#  'Science and Technology Facilities Council',
#  'Searches',
#  'SendTo',
#  'Start Menu',
# ...

# %%
os.listdir()
# Out:
# ['.849C9593-D756-4E56-8D6E-42412F2A707B',
#  'AL DEMO.xlsx',
#  'Apps',
#  'Attachments',
#  'Data with personal information (GDPR compliance)',
#  'Desktop',
#  'desktop.ini',
#  'Document3  -  Compatibility Mode.docx',
#  'Documents',
#  'General - NQCC - PROGRAMME DELIVERY TEAM [UK_OS]',
#  'General - NQCC Team Site',
#  'Hackathon 2023 BME Data.xlsx',
#  'HC_ST one to one',
#  'Heather @ Science and Technology Facilities Council.url',
#  'Microsoft Teams Chat Files',
#  'Monthly Planner (1) (1).xlsx',
#  'Monthly Planner (1).xlsx',
#  'Pictures',
#  'Project Start and End Analysis.xlsx',
#  'Quantum companies.xlsx',
#  'Recordings',
#  'TO MOVE Hackathon Survey Questions.xlsx',
#  'Whiteboards',
#  '~$Monthly Planner (1).xlsx']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\vqa78999\\OneDrive - Science and Technology Facilities Council'

# %%
os.chdir('Documents')

# %%
os.listdir()
# Out:
# ['20230923 Programme Evaluation Update to SLT Mtg Notes.docx',
#  'Active Bystander Toolkit PDF - ENG.pdf',
#  'Custom Office Templates',
#  'Database1.accdb',
#  'Database2.accdb',
#  'Database3.accdb',
#  'Description of NISQ 2022.pdf',
#  'desktop.ini',
#  'DI PBI Reports.pbix',
#  'Documents for Others',
#  'Documents Worked On',
#  'Documents Working On',
#  'File Naming Structure',
#  'File Naming Structure 2',
#  'Hub Partners.xlsx',
#  'Inputs - Activities.xlsx',
#  'Investment in Applications - Pharmaceutics Jan 2024.pdf',
#  'Local Issues',
#  'My Data Sources',
#  'NQCC Benefits Planning - Resources',
#  'NQCC Newsletter_Issue5_Sep2023_v2.1.pdf',
#  'NQCC Org Chart - January 2024.pdf',
#  'NQCC Org Chart - March 2024.pdf',
#  'Office Scripts',
#  'OneNote Notebooks',
#  'PD Team General',
#  'Personal Resources',
#  'Power BI Reports',
#  'Program Evaluation Resources',
#  'Project Prioritisation',
#  'Python Scripts',
#  'QCTL EOI Data.xlsx',
# ...

# %%
os.chdir('Training\\Archer Python Course\\portal-teachingdb-master')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 os.chdir('Training\\Archer Python Course\\portal-teachingdb-master')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Training\\Archer Python Course\\portal-teachingdb-master'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\vqa78999\\OneDrive - Science and Technology Facilities Council\\Documents\\Training\\Archer Python Course\\portal-teachingdb-master'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'bouldercreek_09_2013.txt',
#  'code',
#  'data',
#  'documents',
#  'new_db.sqlite',
#  'plots.csv',
#  'portal_mammals.sqlite',
#  'README.txt',
#  'scatterplot.png',
#  'species.csv',
#  'speciesSubset.csv',
#  'surveys.csv',
#  'surveys2001.csv',
#  'surveys2002.csv',
#  'surveys_complete.csv',
#  'weight_for_year.csv',
#  'yearly_files']

# %%
import pandas as pd
surveys_df = pd.read_csv('surveys.csv')
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
surveys_df['plot_id'].nunique()
# Out:
# 24

# %%
import os
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.getcwd
# Out:
# <function nt.getcwd()>
